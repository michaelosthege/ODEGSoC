# %%
from scipy.integrate import odeint
from scipy.stats import lognorm
import numpy as np
from ode_api import *
from ode_funcs import *
import matplotlib.pyplot as plt
import scipy
import pymc3 as pm

THEANO_FLAGS = 'exception_verbosity=high'
# Out:
# WARNING (theano.configdefaults): install mkl with `conda install mkl-service`: No module named 'mkl'

# %% [markdown]
# # Test 1: Scalar ODE with 1 parameter
#
# $$ y' = exp(-t) - \alpha y \quad y(0) = 0 $$

# %%
#Specify how many stats, initial values, and ode parameters there are
n_states = 1
n_ics = 1
n_odeparams = 1

#Times to evaluate the solution
times = np.arange(0.25,8,1)

#Instantiate the ODEModel
model_1 = ODEModel(odefunc = test_ode_func_1, 
                   y0 = 0,
                   t0 = 0,
                    times = times,
                    n_states = n_states,
                    n_ics = n_ics,
                    n_odeparams = n_odeparams)

# %%
#Simulate the data and create data to learn from
sims, sens = model_1.simulate([0.4,0])


Y = scipy.stats.lognorm.rvs(s = 0.1, scale = sims)


plt.plot(times, sims)
plt.plot(times,Y)

# %%
# Now instantiate the theano custom ODE op
my_ODEop = ODEop(model_1)

# %%
# The probabilistic model
with pm.Model() as first_model:

    # Priors for unknown model parameters
    alpha = pm.HalfNormal('alpha',1)
    y0 = pm.HalfNormal('y0',1)
    sigma = pm.HalfCauchy('sigma',1)

    # Forward model
    all_params = pm.math.stack([alpha, y0],axis=0)
    pprint = tt.printing.Print('all_params')(all_params)
    
    ode_sol = my_ODEop(all_params)
    oprint = tt.printing.Print('ode_sol')(ode_sol)
    
    forward = ode_sol.reshape(Y.shape)
    fprint = tt.printing.Print('forward')(pm.math.log(forward))
    
    

    # Likelihood 
    Y_obs = pm.Lognormal('Y_obs', mu=pm.math.log(forward), sd=sigma, observed=Y)
#     Y_obs = pm.Normal('Y_obs', mu=forward, sd=sigma, observed=Y)
#     Y_obs = pm.Lognormal('Y_obs', mu=forward, sd=sigma, observed=Y)
    
    trace = pm.sample(500, tune=500, init='adapt_diag', target_accept = 0.99)

pm.traceplot(trace)

plt.show()
# Out:
# all_params __str__ = [0.79788456 0.79788456]
# ode_sol __str__ = [0.8533013  0.70173658 0.43278432 0.23784487 0.12290488 0.0611571
#  0.02967723 0.01415011]
# forward __str__ = [[-0.15864257]
#  [-0.35419719]
#  [-0.83751578]
#  [-1.43613664]
#  [-2.09634455]
#  [-2.79430928]
#  [-3.51737528]
#  [-4.258033  ]]
# Auto-assigning NUTS sampler...
# Initializing NUTS using adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sigma, y0, alpha]
# Sampling 2 chains: 100%|██████████| 2000/2000 [05:00<00:00,  5.44draws/s]

# %%
pm.posteriorplot.plot_posterior(trace);

# %%
print(pm.gelman_rubin(trace))

print(pm.effective_n(trace))
# Out:
# {'alpha': 1.0033961028482075, 'y0': 1.0034972978736236, 'sigma': 1.0070279766857095}
# {'alpha': 301.9207200739059, 'y0': 448.5505315615593, 'sigma': 301.5962825442003}

# %% [markdown]
# # Test 2: Scalar ODE with 2 Parameters

# %%
#Specify how many stats, initial values, and ode parameters there are
n_states = 1
n_ics = 1
n_odeparams = 2

#Times to evaluate the solution
times = np.arange(0.25,8,1)

#Instantiate the ODEModel
model_2 = ODEModel(odefunc = test_ode_func_2, 
                   y0 = 0,
                   t0 = 0,
                    times = times,
                    n_states = n_states,
                    n_ics = n_ics,
                    n_odeparams = n_odeparams)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/type.py in dtype_specs(self)
#     268                 'complex64': (complex, 'theano_complex64', 'NPY_COMPLEX64')
# --> 269             }[self.dtype]
#     270         except KeyError:
#
# KeyError: 'object'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/basic.py in constant(x, name, ndim, dtype)
#     245     try:
# --> 246         ttype = TensorType(dtype=x_.dtype, broadcastable=bcastable)
#     247         if not constant.enable:
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/type.py in __init__(self, dtype, broadcastable, name, sparse_grad)
#      50         self.broadcastable = tuple(bool(b) for b in broadcastable)
# ---> 51         self.dtype_specs()  # error checking is done there
#      52         self.name = name
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/type.py in dtype_specs(self)
#     271             raise TypeError("Unsupported dtype for %s: %s"
# --> 272                             % (self.__class__.__name__, self.dtype))
#     273
#
# TypeError: Unsupported dtype for TensorType: object
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/basic.py in as_tensor_variable(x, name, ndim)
#     193     try:
# --> 194         return constant(x, name=name, ndim=ndim)
#     195     except TypeError:
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/basic.py in constant(x, name, ndim, dtype)
#     265     except Exception:
# --> 266         raise TypeError("Could not convert %s to TensorType" % x, type(x))
#     267
#
# TypeError: not all arguments converted during string formatting
#
# During handling of the above exception, another exception occurred:
#
# AsTensorError                             Traceback (most recent call last)
# <ipython-input-8-e41eef436196> in <module>
#      14                     n_states = n_states,
#      15                     n_ics = n_ics,
# ---> 16                     n_odeparams = n_odeparams)
#
# ~/Documents/ODEGSoC/Scripts/ode_api.py in __init__(self, odefunc, y0, t0, times, n_states, n_ics, n_odeparams)
#      17         self._n_ics = n_ics
#      18         self._n_odeparams = n_odeparams
# ---> 19         self._augmented_system = augment_system(self._odefunc)
#      20
#      21
#
# ~/Documents/ODEGSoC/Scripts/ode_api.py in augment_system(ode_func)
#     194     dydp_vec= tt.dvector('dydp')
#     195
# --> 196     dydp = dydp_vec.reshape((t_n,t_m))
#     197
#     198     #Stack the results of the ode_func
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/var.py in reshape(self, shape, ndim)
#     319                                  str(type(ndim)))
#     320
# --> 321         return theano.tensor.basic.reshape(self, shape, ndim=ndim)
#     322
#     323     def dimshuffle(self, *pattern):
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/basic.py in reshape(x, newshape, ndim)
#    5049 def reshape(x, newshape, ndim=None):
#    5050     if ndim is None:
# -> 5051         newshape = as_tensor_variable(newshape)
#    5052         if newshape.ndim != 1:
#    5053             raise TypeError(
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/basic.py in as_tensor_variable(x, name, ndim)
#     198         except Exception:
#     199             str_x = repr(x)
# --> 200         raise AsTensorError("Cannot convert %s to TensorType" % str_x, type(x))
#     201
#     202 # this has a different name, because _as_tensor_variable is the
#
# AsTensorError: ('Cannot convert (n, m) to TensorType', <class 'tuple'>)

# %%
f = augment_system(test_ode_func_2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/type.py in dtype_specs(self)
#     268                 'complex64': (complex, 'theano_complex64', 'NPY_COMPLEX64')
# --> 269             }[self.dtype]
#     270         except KeyError:
#
# KeyError: 'object'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/basic.py in constant(x, name, ndim, dtype)
#     245     try:
# --> 246         ttype = TensorType(dtype=x_.dtype, broadcastable=bcastable)
#     247         if not constant.enable:
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/type.py in __init__(self, dtype, broadcastable, name, sparse_grad)
#      50         self.broadcastable = tuple(bool(b) for b in broadcastable)
# ---> 51         self.dtype_specs()  # error checking is done there
#      52         self.name = name
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/type.py in dtype_specs(self)
#     271             raise TypeError("Unsupported dtype for %s: %s"
# --> 272                             % (self.__class__.__name__, self.dtype))
#     273
#
# TypeError: Unsupported dtype for TensorType: object
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/basic.py in as_tensor_variable(x, name, ndim)
#     193     try:
# --> 194         return constant(x, name=name, ndim=ndim)
#     195     except TypeError:
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/basic.py in constant(x, name, ndim, dtype)
#     265     except Exception:
# --> 266         raise TypeError("Could not convert %s to TensorType" % x, type(x))
#     267
#
# TypeError: not all arguments converted during string formatting
#
# During handling of the above exception, another exception occurred:
#
# AsTensorError                             Traceback (most recent call last)
# <ipython-input-11-be9a462e30eb> in <module>
# ----> 1 f = augment_system(test_ode_func_2)
#
# ~/Documents/ODEGSoC/Scripts/ode_api.py in augment_system(ode_func)
#     194     dydp_vec= tt.dvector('dydp')
#     195
# --> 196     dydp = dydp_vec.reshape((t_n,t_m))
#     197
#     198     #Stack the results of the ode_func
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/var.py in reshape(self, shape, ndim)
#     319                                  str(type(ndim)))
#     320
# --> 321         return theano.tensor.basic.reshape(self, shape, ndim=ndim)
#     322
#     323     def dimshuffle(self, *pattern):
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/basic.py in reshape(x, newshape, ndim)
#    5049 def reshape(x, newshape, ndim=None):
#    5050     if ndim is None:
# -> 5051         newshape = as_tensor_variable(newshape)
#    5052         if newshape.ndim != 1:
#    5053             raise TypeError(
#
# ~/miniconda3/lib/python3.7/site-packages/theano/tensor/basic.py in as_tensor_variable(x, name, ndim)
#     198         except Exception:
#     199             str_x = repr(x)
# --> 200         raise AsTensorError("Cannot convert %s to TensorType" % str_x, type(x))
#     201
#     202 # this has a different name, because _as_tensor_variable is the
#
# AsTensorError: ('Cannot convert (n, m) to TensorType', <class 'tuple'>)

# %%
# Out:
# int
